# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("D:Maged/imdb/imdb_md.csv")
data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
data.drop(columns={'id','imdb_id','homepage','keywords','tagline','original_title'},inplace=True)
# drop uncesssary columns in the dataset

# %%
data.head()
# Out:
#    popularity     budget     revenue  \
# 0   32.985763  150000000  1513528810
# 1   28.419936  150000000   378436354
# 2   13.112507  110000000   295238201
# 3   11.173104  200000000  2068178225
# 4    9.335014  190000000  1506249360
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            10866 non-null  float64
#  1   budget                10866 non-null  int64
#  2   revenue               10866 non-null  int64
#  3   cast                  10790 non-null  object
#  4   director              10822 non-null  object
#  5   overview              10862 non-null  object
#  6   runtime               10866 non-null  int64
#  7   genres                10843 non-null  object
#  8   production_companies  9836 non-null   object
#  9   release_date          10866 non-null  object
#  10  vote_count            10866 non-null  int64
#  11  vote_average          10866 non-null  float64
#  12  release_year          10866 non-null  int64
#  13  budget_adj            10866 non-null  float64
#  14  revenue_adj           10866 non-null  float64
# ...

# %%
data.describe()
# Out:
#          popularity        budget       revenue       runtime    vote_count  \
# count  10866.000000  1.086600e+04  1.086600e+04  10866.000000  10866.000000
# mean       0.646441  1.462570e+07  3.982332e+07    102.070863    217.389748
# std        1.000185  3.091321e+07  1.170035e+08     31.381405    575.619058
# min        0.000065  0.000000e+00  0.000000e+00      0.000000     10.000000
# 25%        0.207583  0.000000e+00  0.000000e+00     90.000000     17.000000
# 50%        0.383856  0.000000e+00  0.000000e+00     99.000000     38.000000
# 75%        0.713817  1.500000e+07  2.400000e+07    111.000000    145.750000
# max       32.985763  4.250000e+08  2.781506e+09    900.000000   9767.000000
#
#        vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean       5.974922   2001.322658  1.755104e+07  5.136436e+07
# std        0.935142     12.812941  3.430616e+07  1.446325e+08
# ...

# %%
ind=data[data['runtime']==0].index
data.drop(ind,axis=0,inplace=True)
data[data['runtime']==0]
#droping movies without a specific runtime "runtime=0".
# Out:
# Empty DataFrame
# Columns: [popularity, budget, revenue, cast, director, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, budget_adj, revenue_adj]
# Index: []

# %%
data['release_date']=pd.to_datetime(data['release_date'])
# Turning "release_date" from "string" to "datetime".
# To be easier to search by date.

# %%
data.sample(10)
# Out:
#        popularity    budget    revenue  \
# 6705     0.538360         0          0
# 10474    1.522478   6000000  138530565
# 411      0.256542         0          0
# 5187     0.159996         0          0
# 2682     0.883228         0          0
# 1607     0.429492   7300000   10329747
# 8273     0.702115         0          0
# 2666     1.134012  60000000   93375151
# 5692     0.422443         0          0
# 3414     1.592819  66000000  177584879
#
#                                                     cast           director  \
# 6705   Jon Heder|Rob Schneider|David Spade|Jon Lovitz...       Dennis Dugan
# 10474  Tom Berenger|Charlie Sheen|Willem Dafoe|Forest...       Oliver Stone
# 411    Maiara Walsh|Diego Boneta|Jocelin Donahue|Andr...     Alberto Marini
# 5187   James Woods|Nick Nolte|Claire Forlani|Daryl Ha...     Michael Polish
# 2682   Meg Ryan|Hugh Jackman|Liev Schreiber|Breckin M...      James Mangold
# ...

# %%
data.genres.mode()
# Which genres are most popular in this dataset.
# Out:
# 0    Drama
# dtype: object

# %%
data.production_companies.mode()
# Which production company has more movies than the other production companies in this dataset.
# Out:
# 0    Paramount Pictures
# dtype: object

# %%
data.director.mode()
# Which director has more movies than the other directors in this dataset.
# Out:
# 0    Woody Allen
# dtype: object

# %%
data.cast.mode()
# Which actor/actress has more movies than the other actors/actresses in this dataset.
# Out:
# 0    Louis C.K.
# dtype: object

# %%
data.release_year.mode()
# Which year has more movies than the other years in this dataset.
# Out:
# 0    2014
# dtype: int64

# %%
data.release_date.dt.month.mode()
# What is the most popular release month
# The most popular month is >>>> September
# Out:
# 0    9
# dtype: int64

# %%
high_revenue=data.sort_values(by=['revenue'],ascending=False).head(10)
high_revenue.genres.mode()
# Finding movies genres that have the highest revenues. The most popular movies genres are "Action|Adventure|Science Fiction".
# Out:
# 0    Action|Adventure|Science Fiction
# dtype: object

# %%
# Thanks!!
